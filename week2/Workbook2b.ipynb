# %%
import pandas as pd
parttwo_df = pd.read_csv('census.csv')
#parttwo_df.head()

my_columns = ['STNAME', 'CTYNAME', 'SUMLEV', 'POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014',
'POPESTIMATE2015']
question7_df = parttwo_df[my_columns]
question7_df = question7_df.where(question7_df['SUMLEV'] == 50)
question7_df = question7_df.dropna()
state_list = question7_df['STNAME'].unique()
#print((state_list))

new_question7_df = pd.DataFrame()
new_question7_df['State'] = state_list
new_question7_df['County'] = question7_df['CTYNAME']
new_question7_df['POPCHANGE'] = 0
new_question7_df.set_index('State', inplace = True)
new_question7_df.head()


for st in new_question7_df.index:
    maxpop = question7_df[question7_df['STNAME'] == st].sort_values(by = ['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014',
'POPESTIMATE2015'], ascending = False).head(1)
    minpop = question7_df[question7_df['STNAME'] == st].sort_values(by = ['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014',
'POPESTIMATE2015'], ascending = True).head(1)
    #print(maxpop['POPESTIMATE2010'])
    #maxpop.cummax()
    maxpop = maxpop.to_numpy()
    minpop = minpop.to_numpy()
    #print(maxpop)
    #print('>>>>>>>>>>>>>>>>>>>>>>>>>>>>')
    #print(minpop)
    #new_question7_df['POPCHANGE'].loc[st] = maxpop
# Out:
# [['Alabama' 'Jefferson County' 50.0 658116.0 657779.0 657704.0 658913.0
#   660368.0 660367.0]]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>
# [['Alabama' 'Greene County' 50.0 9001.0 8910.0 8835.0 8706.0 8553.0
#   8479.0]]
# [['Alaska' 'Anchorage Municipality' 50.0 293405.0 296333.0 298613.0
#   301537.0 300357.0 298695.0]]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>
# [['Alaska' 'Yakutat City and Borough' 50.0 662.0 651.0 653.0 636.0 634.0
#   613.0]]
# [['Arizona' 'Maricopa County' 50.0 3825597.0 3871957.0 3945460.0
#   4015328.0 4090022.0 4167947.0]]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>
# [['Arizona' 'Greenlee County' 50.0 8339.0 8589.0 8768.0 8908.0 9323.0
#   9529.0]]
# [['Arkansas' 'Pulaski County' 50.0 383628.0 386827.0 388984.0 391352.0
#   392490.0 392664.0]]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>
# [['Arkansas' 'Calhoun County' 50.0 5338.0 5286.0 5306.0 5214.0 5188.0
#   5229.0]]
# [['California' 'Los Angeles County' 50.0 9826009.0 9896602.0 9970436.0
#   10045175.0 10109436.0 10170292.0]]
# ...

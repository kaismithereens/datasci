# %%
import pandas as pd
import numpy as np

# %%
def answer_six_v1():
    census_df = pd.read_csv('census.csv') 
    county_df = census_df[census_df['SUMLEV'] == 50]
    return county_df.head()

# %%
answer_six_v1()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
def answer_six():
    census_df = pd.read_csv('census.csv') 
    county_df = census_df[census_df['SUMLEV'] == 50]
    county_df = county_df[['STNAME', 'CTYNAME', 'CENSUS2010POP']]
    for group, frame in county_df.groupby(['STNAME']):
        print('Group', group, 'Frame', frame)

# %%
answer_six()
# Out:
# Group Alabama Frame      STNAME            CTYNAME  CENSUS2010POP
# 1   Alabama     Autauga County          54571
# 2   Alabama     Baldwin County         182265
# 3   Alabama     Barbour County          27457
# 4   Alabama        Bibb County          22915
# 5   Alabama      Blount County          57322
# ..      ...                ...            ...
# 63  Alabama  Tuscaloosa County         194656
# 64  Alabama      Walker County          67023
# 65  Alabama  Washington County          17581
# 66  Alabama      Wilcox County          11670
# 67  Alabama     Winston County          24484
#
# [67 rows x 3 columns]
# Group Alaska Frame     STNAME                            CTYNAME  CENSUS2010POP
# 69  Alaska             Aleutians East Borough           3141
# 70  Alaska         Aleutians West Census Area           5561
# 71  Alaska             Anchorage Municipality         291826
# 72  Alaska                 Bethel Census Area          17013
# ...
